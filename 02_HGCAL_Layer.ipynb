# %% [markdown]
# <a href="https://colab.research.google.com/github/sidhu2690/GEANT4/blob/main/02_HGCAL_Layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
Layer_data = {
    1: 322.155, 2: 323.149, 3: 325.212, 4: 326.206, 5: 328.269, 6: 329.263, 7: 331.326, 8: 332.32,
    9: 334.383, 10: 335.377, 11: 337.44, 12: 338.434, 13: 340.497, 14: 341.491, 15: 343.554,
    16: 344.548, 17: 346.611, 18: 347.605, 19: 349.993, 20: 350.987, 21: 353.375, 22: 354.369,
    23: 356.757, 24: 357.751, 25: 360.139, 26: 361.133, 27: 367.976, 28: 374.281, 29: 380.586,
    30: 386.891, 31: 393.196, 32: 399.501, 33: 405.806, 34: 411.916, 35: 418.221, 36: 424.526,
    37: 430.831, 38: 439.056, 39: 447.281, 40: 455.506, 41: 463.731, 42: 471.956, 43: 480.181,
    44: 488.406, 45: 496.631, 46: 504.856, 47: 513.081
}


innerRadius = 50.0   # cm
outerRadius = 100.0  # cm
s = 5



def generate_data(num_hits):
  gen_data = []

  while len(gen_data) < num_hits:
    x_hit = np.random.uniform(-outerRadius, outerRadius)
    y_hit = np.random.uniform(-outerRadius, outerRadius)
    L = 1
    r = np.sqrt(x_hit**2 + y_hit**2)


    if innerRadius <= r <= outerRadius:
      gen_data.append([x_hit, y_hit, L])


  data_df = pd.DataFrame(gen_data, columns = ['x_hit', 'y_hit', 'L'])
  hits.to_csv("hits.csv", index= False)

  return data_df

hits = generate_data(100)

# %%
df = pd.read_csv('hits.csv')
df.head()
# Out:
#        x_hit      y_hit  L
# 0  25.518632 -55.843981  1
# 1  79.112441  15.287258  1
# 2  19.397620  78.503190  1
# 3  75.984446  21.488981  1
# 4  30.236426  71.506090  1

# %%
def segmented_data():
      data = []

      gen_data = pd.read_csv('hits.csv')
      for hehe, i in gen_data.iterrows():

        x_hit = i.iloc[0]
        y_hit = i.iloc[1]
        L = i.iloc[2]

        i = np.round(x_hit / s)
        j = np.round(y_hit / s)


        x_mm = i * s * 10
        y_mm = j * s * 10
        z_mm = Layer_data.get(L) * 10

        r_mm = np.sqrt(x_mm**2 + y_mm**2 + z_mm**2)
        phi_deg = np.degrees(np.arctan2(y_mm, x_mm))
        theta_rad = np.arccos(z_mm / r_mm)
        theta_deg = np.degrees(theta_rad)
        eta = -np.log(np.tan(theta_rad / 2))

        data.append([L, x_mm, y_mm, i, j, np.round(eta, 2).item(), np.round(phi_deg, 2).item(), np.round(theta_deg, 2).item() ])

      segmented_data = pd.DataFrame(data, columns=['L', 'x_mm', 'y_mm', 'i', 'j', 'i_eta', 'i_phi', 'theta'])
      segmented_data.to_csv("segmented_data.csv", index = False)

      return data

segmented = segmented_data()

# %%
df_segmented = pd.read_csv("segmented_data.csv")
df_segmented.head(5)
# Out:
#      L   x_mm   y_mm     i     j  i_eta  i_phi  theta
# 0  1.0  250.0 -550.0   5.0 -11.0   2.38 -65.56  10.62
# 1  1.0  800.0  150.0  16.0   3.0   2.08  10.62  14.18
# 2  1.0  200.0  800.0   4.0  16.0   2.07  75.96  14.36
# 3  1.0  750.0  200.0  15.0   4.0   2.13  14.93  13.55
# 4  1.0  300.0  700.0   6.0  14.0   2.15  66.80  13.30
